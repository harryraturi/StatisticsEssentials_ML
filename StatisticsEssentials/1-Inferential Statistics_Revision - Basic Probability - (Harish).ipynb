# %% [markdown]
# # Introduction: Inferential Statistics
#
# Welcome to the module on ‘Inferential Statistics’.

# %% [markdown]
# Many a time, you may require a very large amount of data for your analysis which may need too much time and resources to acquire. In such situations, you are forced to work with a smaller **sample of the data**, instead of having the entire data to work with.
#
#
#
# Situations like these arise all the time at big companies like Amazon. For example, say the Amazon QC department wants to know what proportion of the products in its warehouses are defective. Instead of going through all of its products (which would be a lot!), the Amazon QC team can just check a small sample of 1,000 products and then find, for this sample, the defect rate (i.e. the proportion of defective products). Then, based on this sample's defect rate, the team can "infer" what the defect rate is for all the products in the warehouses.
#
#
#
# - **This process of “inferring” insights from sample data is called “Inferential Statistics”**.

# %% [markdown]
# Note that even after using inferential statistics, you would only be able to estimate the population data from the sample data, but not find the exact values. This is because when you don't have the exact data, you can only make reasonable estimates about it with a limited level of certainty. Therefore, when certainty is limited, we talk in terms of probability.

# %% [markdown]
# ## Prerequisites
# You’ll need to brush up on your concepts of probability before you begin this module, specifically the following concepts:
#
# - Basic definition of probability
#
# - Multiplication rule of probability
#
# - Addition rule of probability
#
# - (Combinatorics)
#
#
#
# You can brush up on these topics using the links given below -
#
# 1. Prerequisites for Session 1
#     - https://learn.upgrad.com/course/3094/segment/25649/153610/471487/2441636
# 2. Prerequisites for Session 2
#     - https://learn.upgrad.com/course/3094/segment/25649/153610/471486/2441634
#
#
# You can also solve the practice questions provided in the Resources section.
#
# 1. Optional Questions for Session 1
#     - https://learn.upgrad.com/course/3094/segment/25649/153610/471487/2441637
# 2. Optional Questions for Session 2
#     - https://learn.upgrad.com/course/3094/segment/25649/153610/471486/2441635

# %% [markdown]
# ## Basic Definition of Probability:
#
# #### Q1: The probability of an event is equal to the:
#
# **Options**:
# - Number of favourable outcomes / Number of unfavourable outcomes
#
# - Number of unfavourable outcomes / Number of total outcomes
#
# - Number of favourable outcomes / Number of total outcomes
#
# - Number of total outcomes / Number of favourable outcomes
#
# **Ans**:
# - Number of favourable outcomes / Number of total outcomes
#     - Yes, this is the basic definition of probability.
#
#
# #### Q2: A regular die is thrown. The probability of getting the number 5 is:
#
# **Options**:
# - 5 / 6
#
# - 1 / 6
#
# - 1 / 3
#
# - 1 / 2
#
# **Ans**:
# - 1 / 6
#     - Number of favourable outcomes = 1 (i.e. the outcome that the die throws 5). Total number of outcomes = 6 (The die could throw 1, 2, 3, 4, 5 or 6). Probability = Number of favourable outcomes / Total number of outcomes = 1 / 6.
#
#
#
# #### Q3:  A regular die is thrown. The probability of getting an even number is:
#
# **Options**:
# - 2 / 6
#
# - 3 / 6
#
# - 1 / 6
#
# - 4 / 6
#
# **Ans**:
# - 3 / 6
#     - Number of favourable outcomes = 3 (the die throws 2, 4, 6). Total number of outcomes = 6 ( the die could throw 1, 2, 3, 4, 5 or 6). Probability = Number of favourable outcomes / Total number of outcomes = 3 / 6
#
#
#
# #### Q4:  Out of the following values, which is/are the possible value(s) of probability?
#
# **Options**:
#
# - 0.1
#
# - -0.1
#
# - 1.0
#
# - 10
#
# **Ans**:
#
# - 0.1
#     - The probability of an event can only be between 0 and 1
#
# - 1.0
#     - The probability of an event can only be between 0 and 1
#
#
# #### Q5: The probability of all possible events adds up to:
#
# **Options**:
# - 1
#
# - 0
#
# - Infinity
#
# - More information needed
#
# **Ans**:
# - 1
#     - The probability of all possible events adds up to 1, as the number of favourable events becomes the total number of events.
#
#
# #### Q6: A regular die is thrown. The probability of getting the number 7 is:
#
#
#
# **Options**:
# - 1 / 6
#
# - 0
#
# - 7 / 6
#
# - 1 / 7
#
# **Ans**:
# - 0
#     - Number of favourable outcomes = 0 (you can never get a 7 by throwing a regular die). Total number of outcomes = 6 (the die could throw 1, 2, 3, 4, 5 or 6). Probability = Number of favourable outcomes / Total number of outcomes = 0.

# %% [markdown]
# ## Optional Questions
# ### Advanced Concepts in Probability
#
# #### Q1: A regular die is thrown. The probability of getting the number 4 or 5 in this throw is:
#
#
#
# **Options**:
# 0
#
# 1 / 6
#
# 1 / 3
#
# 1 / 2
#
# **Ans**:
# 1 / 3
# Define X as the number achieved after throwing the die. You know that P(X = 4) = 1 / 6 and P(X = 5) = 1 / 6. Now, using addition rule of probability, you will get that P(X = 4 or 5) = P(X = 4) + P(X = 5) = 1 / 6 + 1 / 6 = 1 / 3.
#
#
# #### Q2: A regular die is thrown. The probability of getting the number 4 and 5 in this throw is:
#
#
# **Options**:
# 0
#
# 1 / 6
#
# 1 / 3
#
# 1 / 2
#
# **Ans**:
# 0
# It is impossible to get two numbers in one throw of the die.
#
#
#
# #### Q3:  A regular die is thrown. The probability of getting the number 4 in the first throw and 5 in the second throw is:
#
# **Options**:
# 2 / 6
#
# 1 / 36
#
# 20 / 36
#
# 9 / 36
#
# **Ans**:
# 1 / 36
# Again, P(getting the number 4) = 1 / 6 and P(getting the number 5) = 1 / 6. Now, using multiplication rule, you get that P(getting the number 4 in the 1st trial AND the number 5 in the 2nd trial) = P(getting the number 4 in the 1st trial)*P(getting the number 5 in the second trial) = 1 / 6 * 1 / 6 = 1 / 36.
#
#
#
# #### Q4:  A fair coin is tossed. The probability of getting a head or a tail is?
#
# **Options**:
# 1
#
# 0.25
#
# 0.5
#
# 0
#
# **Ans**:
# 1
# P(heads) = 0.5, P(tails) = 0.5, Using addition rule, you have P(heads OR tails) = 0.5 + 0.5 = 1.
#
#
# #### Q5: A fair coin is tossed. The probability of getting a head and a tail is?
#
#
# **Options**:
# 1
#
# 0.25
#
# 0.5
#
# 0
#
# **Ans**:
#
# 0
# It is impossible to get heads and tails in one toss of the coin.
#
#
# #### Q6: A fair coin is tossed. The probability of getting a head in the 1st toss and a tail in the 2nd toss is?
#
# **Options**:
# 1
#
# 0.25
#
# 0.5
#
# 0
#
# **Ans**:
# 0.25
# P(heads) = 0.5, P(tails) = 0.5, Using multiplication rule, you have P(heads in 1st toss AND tails in 2nd toss) = P(heads in 1st toss)*P(tails in 2nd toss) = 0.5*0.5 = 0.25.
#
#
# #### Q7: Advanced Concepts in Probability
# MS Dhoni is selecting the Indian cricket team, and has selected 8 players. For the remaining 3 players, he has 5 options to choose from -
#
# Jasprit Bumrah
# Amit Mishra
# Axar Patel
# Ravindra Jadeja
# Bhubaneshwar Kumar
# For example
#
# He could select like this -
#
# Jasprit Bumrah
# Bhubaneshwar Kumar
# Ravindra Jadeja
# Or like this -
#
# Amit Mishra
# Axar Patel
# Ravindra Jadeja
# and so on.
#
# In total, how many different combinations of 3 players can he pick for the team?
#
# **Options**:
# 3C5
#
#
# 5C3
#
#
# 8C3
#
#
# 8C5
#
# **Ans**:
# 5C3
#
# Let’s say we have n distinct objects, from which we are to select r of them. The number of different combinations in which this selection can be done, is given by
# nCr. For example, here, we have 5 players, out of which, 3 are to be selected. The number of combinations in which 3 players can be selected, thus, is given by 5C3 (10).

# %% [markdown]
# # Introduction: Basics of Probability
# Welcome to the session on ‘Basics of Probability’.
#
#
# In this session, you will learn a few basic concepts of probability through a specific example. The broad agenda for this session is as follows:
#
# - Random variables
#
# - Probability distributions
#
# - Expected value

# %% [markdown]
# # Pre-Reads
#
# Please Note: This is an additional resource. The link for this session has been integrated at an appropriate place in the main Inferential module.
#
#
#
# Before going through this session, you should understand the basic definition of probability. In order to understand that, you can go through the following links -
#
# - Math is Fun - Probability
#     - https://www.mathsisfun.com/data/probability.html
# - Mathopolis - Probability
#     - http://www.mathopolis.com/questions/q.php?id=700&site=1&ref=/data/probability.html&qs=700_701_702_1475_1476_1477_2175_2176_2177_2178

# %% [markdown]
# # Random Variables
#
# Welcome to the first session on inferential statistics! This will be a very interactive session, with a lot of questions that will compel you to think about a concept, helping you explore it more actively.

# %% [markdown]
# Recall the original question: In the long run (i.e. if it is played a lot of times), is this game profitable for the players or for the house? Or will everybody break even in the long run?
#
#
#
# Recall that we established a three-step process for answering this question:
#
# 1. Find all the possible combinations
#
# 2. Find the probability of each combination
#
# 3. Use the probabilities to estimate the profit/loss per player
#
#
#
# We have completed step 1, i.e. finding all the possible combinations. Now, let’s proceed to step 2, i.e. finding the probability of each combination. What are the steps involved in finding the probability? Let’s hear more from Professor Tricha on this:

# %% [markdown]
# - Qualifying out comes
#     - Random variable
#         1. Denoted By X
#         2. Any variable that associates an outcomes to a number
#
# - X = Number of Red balls
#
#
#
# - When we got 1-Blue & 3-Red >> X=3
# - When we got 2-Blue & 2-Red >> X=2

# %% [markdown]
# ### Question:
# Suppose we have 5 Balls = 2-Blue & 3-Red in a bag.
# Player need to pick one ball from the bag at time and repeat this 4 times with replacement?
# So they said the possible out come is  = 16
#
# **Ans**: We can also calculate total out come with help of nCr i.e. combination
# - nCr = n!/r! * (n-r)!
# - where n = 4 & r= 0 to 4

# %% [markdown]
# # Probability Distributions - I
#
#
# Recall that, in our UpGrad game example, we need to find out if the game would be profitable for the players or for us (i.e. the house) in the long run. The three-step process for this is:
#
# 1. Find all the possible combinations
#
# 2. Find the probability of each combination
#
# 3. Use the probabilities to estimate the profit/loss per player
#
#
#
# So far, we have completed step 1, and are on step 2, i.e. finding the probability of each combination. For this purpose, we defined a random variable X which helped us convert the outcomes of our experiment to something measurable. Now, let’s actually find the probability of each of these combinations.

# %% [markdown]
# ![pob1.jpg](attachment:pob1.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q: Probability
# Based on this histogram, can you tell what the probability will be for X = 2?
#
# (Give your answer as a number rounded to 2 digits after the decimal point. For example, instead of 90%, type 0.90)
#
# **Ans**: 26/75
# The correct answer is 0.35. Let's listen to Prof. Tricha as she tells us why.

# %% [markdown]
# #### Probability Distribution:
#
# | X | P(x) |
# | --- | --- |
# | 0 | 2/75 == 0.027 |
# | 1 | 12/75 == 0.160 |
# | 2 | 26/75 == 0.347 |
# | 3 | 25/75 == 0.333 |
# | 4 | 10/75 == 0.133 |

# %% [markdown]
# ![pob2.jpg](attachment:pob2.jpg)
#
# - Here we have our probability in Tabular form and Bar chart

# %% [markdown]
# # Probability Distributions - II
#
# So basically, a probability distribution is ANY form of representation that tells us the probability for all possible values of X. It could be any of the following:
#
# A table
#
# ![image.png](attachment:image.png)
#
# - Figure 2 - Tabular Form of Probability Distribution

# %% [markdown]
# - A chat
#
# ![image.png](attachment:image.png)
#
# - Figure 3 - Bar Chart Form of Probability Distribution

# %% [markdown]
# - An equation
#
# P(x) = x/21
#
# (for x = 1, 2, 3, 4, 5 and 6)

# %% [markdown]
# #### Q: Probability Distributions
# Which of the following probability distributions is/are NOT valid, complete probability distribution(s)?
#
# A -
#
# | X |      	Probability |
# | --- | --- |
# | 0 |	0.1 |
# | 2 | 	0.2 |
# | 3 |	0.3 |
# | 4	| 0.4 |
#
# B -
#
# | X |      	Probability |
# | --- | --- |
# | 0	| 0.15 |
# | 0.5 |	0.15 |
# | 1 |	0.20 |
# | 1.5 |	0.25 |
# | 2 |	0.25 |
#
# C -
#
# | X |      	Probability |
# | --- | --- |
# |0|	-0.05|
# |1|	0.20|
# |2|	0.25|
# |3|	0.35|
# |4|	0.40|
#
#
# **Options**:
# - Only Table A is an invalid distribution
#
# - Only Table B is an invalid distribution
#
# - Only Table C is an invalid distribution
#
# **Ans**:
#
# - Only Table C is an invalid distribution
#     - This is not a valid distribution. P(X = 0) has been given as -0.05. However, there is no such thing as a negative probability. Also, the total probability is 1.1, which does not make sense. The total of all probabilities in a probability distribution should be equal to 1.

# %% [markdown]
# # Expected Value - I
#
# Again, let’s go back to the three-step process we followed to find whether the UpGrad red ball game was profitable for the players or for the house:
#
# 1. Find all the possible combinations
#
# 2. Find the probability of each combination
#
# 3. Use the probabilities to estimate the profit/loss per player
#
# Now that we have completed steps 1 and 2, let’s move on to step 3 where we will use the probabilities we calculated to estimate the profit/loss per player.

# %% [markdown]
# #### Q: Number of People Drawing 1 Red Ball
# Suppose 1,000 people play the game. How many people are expected to draw 1 red ball (i.e. get 1 red ball after playing the game)?
#
# (Recall that P(1 red ball) = 0.16)
#
# [You’re not expected to know the right answer at this point. This question is given just to get you thinking in the right direction.]
#
#
# **Ans**:
# The correct answer is 160. Let's listen to Prof. Tricha as she tells us why.

# %% [markdown]
# #### Number of Players
#
# - P(X=1) = 0.16
#     - Total no. of playes = 1000
#     - No. of players with 1 red ball = 1000*0.16 = 160
#
# - P(X=2) = 0.347
#     - Total no. of playes = 1000
#     - No. of players with 2 red ball = 1000*0.347 = 347
#
# - No. of players with 0 red ball = 1000*0.0.27 = 27
# - No. of players with 3 red ball = 1000*0.333 = 333
# - No. of players with 4 red ball = 1000*0.133 = 133
#
#
# - Total number of red balls
#     - = 0*27 + 1*160 + 2*347 + 3*333 + 4*133 = 2385
#
# - Average no. of red balls for 1 game = 2385/1000 = 2.385

# %% [markdown]
# So, the expected value for a variable X is the value of X we would “expect” to get after performing the experiment once. It is also called the expectation, average, and mean value. Mathematically speaking, for a random variable
#
# X that can take values
# x1,x2,x3,.....,xn, the expected value (EV) is given by:
#
# EV(X)=x1∗P(X=x1)+x2∗P(X=x2)+x3∗P(X=x3)+.......+xn∗P(X=xn)
#
#
# As you may recall, for our red ball game, the expected value came out to be 2.385. What does that mean? How does that even help us with our original question, which was how much money, on average, are the players expected to make?

# %% [markdown]
# #### Expected value of money won after 1 game
#
# - X can take two value: +150 and -10
# - P(X = +150) = P(4 red balls)
#     - = 0.133
# - P(X = -10) = P(0, 1,2 and 3 red balls)
#     - = 0.027 + 0.160 + 0.347 + 0.333
#     - = 0.867
#
#
# - So, EV = (150*0.133) + (-10*0.867)
#     - = + 11.28
#
#
# - So, in this way Casino will lose the money as expected value is +ve but it should be -ve
#     - either we can decrease the prize money (eg. 100)
#     - or increase the penality (eg. 50)

# %% [markdown]
# #### Q: Expected Value
# Now, can you calculate the expected value of X (where X is the money won by the player after playing the game once)?
#
# | X (Money won after playing once) |	Probability |
# | --- | --- |
# | +150	| 0.133 |
# | -10	| 0.867 |
#
#
# You can use this probability distribution to find the answer.
#
#
# **Ans**:
# The correct answer is 11.28.

# %% [markdown]
# # Expected Value - II
#
# Let’s try it for a different activity. Let’s say that you’re throwing a dice. You’ve defined X as the number obtained upon throwing it once. By calculations, you would find that the expected value for this is 3.5. Let’s see what our simulations show:

# %% [markdown]
# Now, you may recall that the expected value of a player’s winnings after playing our game once was ₹11.28. We said that reducing the prize money and/or increasing the penalty for our game might make the expected value negative. Let’s see how much we need to reduce or increase the prize money.

# %% [markdown]
# #### Q: Expected Value of Player's Winnings
# So, the expected value of a player’s winnings is positive, but we want to make it negative. Which of the following changes to the game would make the expected value negative?
#
# **Options**:
# - Increase the penalty to ₹25
#
# - Decrease the prize money to ₹90
#
# **Ans**:
# - Increase the penalty to ₹25
#     - Keeping the prize money as ₹150 and increasing the penalty to ₹25 would make the expected value (0.133 * 150) + (0.867 * -25) = -1.725, which is a negative value.
#
#
#
# #### Q: Expected Value of Player's Winnings
# Suppose we change the game’s rules to the following:
#
# | Outcome	| Prize |
# | --- | --- |
# | 4 red balls	| +150 |
# | 4 blue balls	| -150 |
# | Any other outcome	| -10 |
#
# What will be the expected value now for X (the amount of money won by a player after playing the game once)?
# **Options**:
# -2.5
#
# -5
#
# +2.5
#
# +7.5
#
# **Ans**:
# +7.5
#
# Recall that the expected value of a random variable is given by
# x
# 1
#  *P(X=
# x
# 1
#  ) +
# x
# 2
# *P(X=
# x
# 2
# ) +
# x
# 3
# *P(X=
# x
# 3
# ) + ……. +
# x
# n
# *P(X=
# x
# n
# ), where
# x
# 1
# ,
# x
# 2
# ,
# x
# 3
#  …..
# x
# n
#  are all the different possible values of X. So, the expected value here would be 150*P(X = 150) + (-150)*P(X = -150) + (-10)*P(X = -10). Now, P(X = 150) = P(getting 4 red balls) = 0.133. Also, P(X = -150) = P(getting 4 blue balls) = 0.027 and P(X = -10) = P(getting 1, 2 or 3 red balls) = 0.840. Putting in those values, we get EV(X) = (150*0.133) + (-150*0.027) + (-10*0.840) = +7.5.

# %% [markdown]
# Recall the problem you saw earlier, where we were asked by a company to suggest whether it should invest in a given project or not. We had made this probability distribution for X, the net revenue of the project.
#
#
#
# | X (Net Revenue of Project, in ₹ crores)	|    P(x)    |
# | --- | --- |
# |-305	|0.1|
# |+15	|0.7|
# |+95	|0.2|
#
#
# Now, we are in a position to find the expected value for X, the return of the project. This is called the expected return. If it comes out to be negative, we can say that the project is not worth investing in.

# %% [markdown]
# #### Q: Expected Return
# Find the expected value of X if its probability distribution is as given in the table above. (Answer in terms of crores.)
#
# The expected value of X, which is also called the expected return, is equal to
#
#
#
# (-305)*P(X=-305) + (+15)*P(X=+15) + (+95)*P(X=+95) = (-305)*0.1 + (+15)*0.7 + (+95)*0.2 = -1 crore rupees.
#
#
#
# So, the expected return of the project is -1 crore rupees. Hence, we can conclude that the project is not worth investing in.

# %% [markdown]
# - You can find more examples of expected returns here.
#     - https://corporatefinanceinstitute.com/resources/knowledge/trading-investing/expected-return/

# %% [markdown]
# # Summary: Basics of Probability
#
# In the first section, you learnt how to quantify the outcomes of events by using random variables.
#
#
#
# For example, recall that we quantified the colours of the balls we would get after playing our game by assigning a value of X to each outcome. We did so by defining X as the number of red balls we would get after playing the game once.
#
# ![image.png](attachment:image.png)
#
# - Figure 4 - Quantifying Using Random Variables

# %% [markdown]
# Next, we found the probability distribution, which was a distribution giving us the probability for all possible values of X.
#
#
#
# We created this distribution in a tabular form:
#
# ![image.png](attachment:image.png)
#
# - Figure 5 - Tabular Form of Probability Distribution

# %% [markdown]
# We also created it in a Frequency Distribution chart:
#
# ![image.png](attachment:image.png)
#
# - Figure 6 - Bar Chart Form of Probability Distribution

# %% [markdown]
# You saw that, in the bar chart form, we were able to visualise the probability in a much better way., Thus, this form is used more widely as it helps you see trends easily.
#
#
#
# Then, we went on to find the expected value for X, the money won by a player after playing the game once. The expected value (EV) for X was calculated using the formula:
#
#
#
# EV (X) = x_{1}*P(X=x_{1})+x_{2}*P(X=x_{2})+....................+x_{n}*P(X=x_{n})
#
#
#
# Another way of writing this is
#
#
#
# EV(X) = \sum_{i=1}^{i=n}x_{i}*P(X=x_{i})
#
#
#
# Calculating the answer this way, we found the expected value to be +11.28.
#
#
# In other words, if we conduct the experiment (play the game) infinite times, the average money won by a player would be ₹11.28. Hence, we decided that we should either decrease the prize money or increase the penalty to make the expected value of X negative. A negative expected value would imply that, on average, a player would be expected to lose money and the house would profit.

# %% [markdown]
# # Practice Questions
#
#
# Let's say that Rajya Laxmi Bank has given student loans to 10,000 people. However, the government wants to ensure that the bank is not giving away very risky loans and, hence, wants to know the “Expected Loss” of the bank’s student loan portfolio.
#
#
#
# The expected loss is basically the expected value of the money lost by the bank due to people defaulting on their loans, i.e. not paying their EMIs.
#
#
#
# The data that the bank uses to calculate the expected loss, looks like this -
#
#
#
# |Customer No.	|Exposure at Default (in ₹ lakh) |	Recovery (%)	|Probability of Default|
# | --- | --- | --- | --- |
# |00001	|11.50	|20%	|0.007|
#
#
# Here,
#
# - Exposure at default (EAD) is the total money owed by the customer in case of default
#
# - Recovery (R) is the percentage of the exposed money that the bank would be able to recover.
#
#     - For example, in the above example, the bank would recover 20% of the exposed money, i.e. 20%*11.5 = ₹2.3 lakh.
#
# - Probability of default (PD) is the probability that the customer will default. This is calculated for each customer using a number of factors such as family income, university attended, etc.

# %% [markdown]
# #### Q1: Expected Loss
# Now, to find the expected loss, the bank has created the following table. As you already know, the probability of customer 1 being a defaulter is 0.007 and that of the customer not being a defaulter is 0.993. Now, in the case of default, what would be the value of X, i.e. the money lost by the bank?
#
# |Defaulter/Non-defaulter	  | Probability |  	X (Money Lost by Bank) |
# | --- | --- | --- |
# |Defaulter	|0.007	| - |
# |Non-defaulter	|0.993	| 0 |
#
#
# **Options**:
# - ₹2.3 lakh
#
# - ₹9.2 lakh
#
# - ₹11.5 lakh
#
# - ₹57.5 lakh
#
# **Ans**:
# - ₹9.2 lakh
#     - The amount recovered would be equal to 20% of 11.5 lakh, i.e. ₹2.3 lakh. However, X is defined as the money lost by the bank. So, the amount lost would be equal to the total money exposed, i.e. ₹11.5 lakh, minus the money recovered, i.e. ₹2.3 lakh. That would mean that the money lost = 11.5 - 2.3 = ₹9.2 lakh.
#
# #### Q2: Now, the bank has the following data -
#
# |Defaulter/Non-defaulter	  | Probability |  	X (Money Lost by Bank) |
# | --- | --- | --- |
# |Defaulter	|0.007	| - |
# |Non-defaulter	|0.993	| 0 |
#
#
# What would be the expected loss (expected value of the money lost by the bank)?
#
# **Options**:
# - ₹6440
#
# - ₹9.2 lakh
#
# - ₹9,200
#
# - ₹6.44 lakh
#
# **Ans**:
# - ₹6440
#     - The random variable X has two possible values, 9.2 lakh for when the customer defaults, and 0 for when the customer doesn’t. So, the Expected value = 9.2 lakh*P(X = 9.2 lakh) + 0*P(X=0) = 9,20,000*(0.007) + 0*(0.993) = 6,440
#
#
#
# #### Q3: Expected Loss
# So, in general, what would be the expected loss?
#
# **Options**:
# - PD*EAD*R
#
# - PD*EAD*(1-R)
#
# - (1-PD)*EAD*R
#
# **Ans**:
# - PD*EAD*(1-R)
#     - X can take two values. When the customer defaults, X = EAD - (EAD*R) = EAD*(1-R). When she/he doesn’t, X = 0. So, the Expected value = EAD(1-R)*P(X = EAD(1-R)) + 0*P(X=0) = EAD*(1-R)*PD + 0
#
#
# #### Q4: Expected Loss
# Now, the bank wants to find the total expected loss. This is done by calculating the expected losses for each of the 10,000 customers and then adding them up.
#
# The data for all the customers of the bank is given in the file Inferential Statistics - Student Loan.csv. What would be the value of the total expected loss?
#
# **Options**:
# - ₹1.25 crores
#
# - ₹4.93 crores
#
# - ₹6.18 crores
#
# - ₹3.09 crores
#
# **Ans**:
#
# - ₹4.93 crores
#     - As you saw in the previous question, expected loss because of the first customer is ₹6,440. In general, it is given by PD*EAD*(1-R) for each customer. Using R or Excel, you can find the expected loss for each customer using this formula. Adding up all of these 10,000 customers' expected losses, we get that the total expected loss = ₹4.93 crores.

# %% [markdown]
# In fact, banks are also required to report the unexpected loss. If you want to read more on how the expected loss and unexpected loss are calculated, you can find that here.
# - https://financetrain.com/expected-loss-unexpected-loss-and-loss-distribution/

# %% [markdown]
# # Graded Questions
#
# A roulette wheel is a game found in many casinos. Let’s go through it and understand how the roulette wheel's design ensures that, in the long run, the player always loses and the house always wins.
#
#
# This is a European roulette wheel.
#
# ![image.png](attachment:image.png)
#
# - It contains the numbers 0 to 36 written in an irregular sequence.
# - The players can bet on any number from 0 to 36.
#
# - For example, let’s say that Kriti bets £100 on the number 5.
# - Now, a ball would be dropped into the wheel, which is then given a spin. If the ball lands on the pocket marked 5, Kriti would win (£100)*36 = £3,600, resulting in net winnings of £3,600 - £100 = £3,500.
# - However, if the ball lands on any other pocket, Kriti would not win anything, resulting in net winnings of £0 - £100 = - £100.
#
#
# Let’s see what the expected value is for Kriti’s net winnings if she plays this game and bets £100 on the number 5.

# %% [markdown]
# #### Q: European Roulette Wheel
# First of all, what is the probability of Kriti winning the game if she bets on the number 5?
#
# **Options**:
# - 1/36
#
# - 1/37
#
# - 5/36
#
# - 5/37
#
# **Ans**:
# - 1/37
#     - There are a total of 37 equally likely possibilities (0 to 36). However, there is only one possibility in which Kriti will win, i.e. the one in which the ball would land on the pocket marked 5. Hence, the probability of her winning the game is 1/37.
#
#
#
# #### Q: European Roulette Wheel
# Now, let’s say that we define the random variable X as Kriti’s net winnings if she plays this game and bets £100 on the number 5. What is the expected value of X?
#
# **Options**:
# - £97.30
#
# - -£2.70
#
# - £98.15
#
# - -£1.85
#
# **Ans**:
# - -£2.70
#     - There are two possible values of X, 3,500 and -100. The probability of Kriti’s net winnings being 3,500 is basically the probability of her winning the game, which, as we saw in a previous question, is 1/37. The probability of her net winnings being equal to -100 is basically the probability of her losing the game, which is 36/37. So, the expected value of X = P(X=-100)*(-100) + P(X=3500)*3500 = (36/37)*(-100)+(1/37)*(3500) = -2.70.

# %% [markdown]
# ### This is an American roulette wheel.​​
#
# ![image.png](attachment:image.png)
#
# - The only difference between the American roulette wheel and the one you saw before,
# - i.e. the European roulette wheel, is that, in addition to the numbers 0 to 36, it  contains a number ‘00’.
# - The player can bet on any number from 1 to 36.

# %% [markdown]
# #### Q: American Roulette Wheel
# Now, again, let’s define the random variable X as Kriti’s net winnings if she plays this game and bets £100 on the number 5. What is the expected value of X this time?
#
#
# **Options**:
# - £97.30
#
# - -£2.70
#
# - £94.74
#
# - -£5.26
#
# **Ans**:
# - -£5.26
#     - Again, there are two possible values of X, 3,500 and -100. However, this time, the probability of Kriti’s net winnings being 3,500 is 1/38, as there are a total of 38 possible outcomes. The probability of her net winnings being equal to -100, basically the probability of her losing the game, is now 37/38. So, the expected value of X = P(X=-100)*(-100) + P(X=3500)*3500 = (37/38)*(-100)+(1/38)*(3500) = -5.26.

# %% [markdown]
# If you want to read more on this topic, specifically, how other games' designs ensure a negative expected value, go through this link.
# - http://www.dehn.wustl.edu/~blake/courses/WU-Ed6021-2012-Summer/handouts/Expected_Value.pdf

# %% [markdown]
# Thank you 🙏 😊
